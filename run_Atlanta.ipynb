# %% [markdown]
# # data_test

# %%
! pip install torch==1.0.0
# Out:
# ...
#      |████████████████████████████████| 591.8MB 16kB/s
# ERROR: torchvision 0.6.0+cu101 has requirement torch==1.5.0, but you'll have torch 1.0.0 which is incompatible.
# ...
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
# ...

# %%
# !git clone https://github.com/mhsamavatian/DAP
# Out:
# Cloning into 'DAP'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 427 (delta 43), reused 48 (delta 23), pack-reused 356
# Receiving objects: 100% (427/427), 89.24 MiB | 41.88 MiB/s, done.
# Resolving deltas: 100% (240/240), done.

# %%
# %cd DAP/data
# Out:
# /content/DAP/data

# %%
# !ls -a
# Out:
# .	   geohash_to_poi_vec.csv   sample_daylight.csv
# ..	   geohash_to_text_vec.csv  Sample_Weather.tar.gz
# .DS_Store  readme.md		    train_set.7z

# %%
# !apt-get install p7zip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip is already the newest version (16.02+dfsg-6).
# p7zip set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.

# %%
!7z x train_set.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 7399321 bytes (7226 KiB)
#
# Extracting archive: train_set.7z
# --
# Path = train_set.7z
# Type = 7z
# Physical Size = 7399321
# Headers Size = 533
# Method = LZMA2:26
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 24
# Size:       496921429
# Compressed: 7399321

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/Shared\ drives/shared_disk/pytorch-GAN-timeseries
# Out:
# /content/drive/Shared drives/shared_disk/pytorch-GAN-timeseries

# %%
! pwd
# Out:
# /content/drive/Shared drives/shared_disk/pytorch-GAN-timeseries

# %%
! python accident_dataset.py
# Out:
# (36994, 200)
# (7974, 200)
# (7974, 8, 25)
# 0 torch.Size([64, 8, 25])
# 0

# %% [markdown]
# # run

# %%
! pip install torchvision==0.2.1
# Out:
# ...
#      |████████████████████████████████| 61kB 3.1MB/s
# ...
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
# ...

# %%
! pip install Pillow==6.1
# Out:
# ...
#      |████████████████████████████████| 2.1MB 4.6MB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ...

# %%
! pip install tensorboardX==1.6
# Out:
# ...
#      |████████████████████████████████| 133kB 4.9MB/s
# ...

# %%
! python main.py --dataset accident --dataset_path /content/DAP/data/ --city Atlanta --batchSize 64 --gen_type cnn
# Out:
# Namespace(alternate=False, batchSize=64, checkpoint_every=5, city='Atlanta', cuda=False, dataset='accident', dataset_path='/content/DAP/data/', delta_condition=False, delta_lambda=10, dis_type='cnn', epochs=50, gen_type='cnn', imf='images', logdir='log', lr=0.0002, manualSeed=None, netD='', netG='', nz=100, outf='checkpoints', run_tag='', tensorboard_image_every=5, workers=2)
# Random Seed:  7974
# You have a cuda device, so you might want to run with --cuda as option
# (14600, 200)
# (2630, 200)
# (2630, 8, 25)
# |Discriminator Architecture|
#  CausalConvDiscriminator(
#   (tcn): TCN(
#     (tcn): TemporalConvNet(
#       (network): Sequential(
#         (0): TemporalBlock(
#           (conv1): Conv1d(25, 10, kernel_size=(8,), stride=(1,), padding=(7,))
#           (chomp1): Chomp1d()
#           (relu1): ReLU()
#           (dropout1): Dropout(p=0)
#           (conv2): Conv1d(10, 10, kernel_size=(8,), stride=(1,), padding=(7,))
#           (chomp2): Chomp1d()
# ...

# %%
#! python main.py --dataset accident --dataset_path /content/DAP/data/ --dis_type lstm

# %%
! pwd
# Out:
# /content/drive/Shared drives/shared_disk/pytorch-GAN-timeseries

# %%
# !mkdir output

# %%
# !ls -a
# Out:
# accident_dataset.py				       main.py
# btp_dataset.py					       models
# checkpoints					       output
# DAP						       output.npy
# data.ipynb					       __pycache__
# feature-analysis3-Acc_pred_model_Final-only_one.ipynb  run_Atlanta.ipynb
# generate_dataset.py				       run_Austin.ipynb
# images						       utils.py
# log

# %%
! python generate_dataset.py --checkpoint_path checkpoints/Atlanta_netG_epoch_25.pth --output_path output/Atlanta25 --dataset accident --dataset_path none --size 10000 --seqlen 8

# %%
import numpy as np
import pandas as pd

raw = np.load('output/'+'Atlanta25'+'.npy')
print(raw.shape)
raw = raw.reshape(-1,8*25)
print(raw.shape)

df = pd.DataFrame(raw)
df
# Out:
# (10000, 8, 25)
# (10000, 200)
#                0             1    ...           198           199
# 0     4.156028e-39  8.465831e-18  ...  2.291770e-27  1.490439e-22
# 1     6.941869e-33  1.996471e-12  ...  1.730309e-26  1.752406e-22
# 2     1.265043e-32  5.417794e-13  ...  6.457172e-17  1.071031e-13
# 3     4.156028e-39  1.530876e-27  ...  4.156028e-39  4.156028e-39
# 4     4.156028e-39  5.414595e-23  ...  1.491846e-13  7.099115e-12
# ...            ...           ...  ...           ...           ...
# 9995  2.603055e-12  8.645107e-05  ...  3.012145e-32  5.170499e-26
# 9996  4.156028e-39  1.988032e-23  ...  4.695604e-23  1.534138e-19
# 9997  4.156028e-39  1.083740e-22  ...  4.156028e-39  4.156028e-39
# 9998  4.156028e-39  8.200836e-16  ...  4.156028e-39  4.156028e-39
# 9999  4.156028e-39  4.552016e-25  ...  4.602108e-33  1.770161e-25
#
# [10000 rows x 200 columns]

# %%
! python generate_dataset.py --checkpoint_path checkpoints/Atlanta_netG_epoch_49.pth --output_path output/Atlanta49 --dataset accident --dataset_path none --size 10000 --seqlen 8

# %%
import numpy as np
import pandas as pd

raw = np.load('output/'+'Atlanta49'+'.npy')
print(raw.shape)
raw = raw.reshape(-1,8*25)
print(raw.shape)

df = pd.DataFrame(raw)
df
# Out:
# (10000, 8, 25)
# (10000, 200)
#                0             1    ...           198           199
# 0     1.012404e-17  1.665951e-07  ...  7.401213e-05  2.520235e-04
# 1     7.086747e-09  5.975384e-04  ...  1.308478e-10  3.519318e-10
# 2     2.958548e-28  1.776898e-11  ...  1.434084e-09  1.212339e-09
# 3     1.218781e-18  1.056203e-07  ...  7.054894e-07  1.151243e-06
# 4     3.385828e-27  2.206094e-11  ...  2.779806e-11  3.358609e-11
# ...            ...           ...  ...           ...           ...
# 9995  4.738575e-15  2.516924e-06  ...  7.620293e-08  2.926867e-07
# 9996  1.139630e-36  8.210513e-15  ...  3.281309e-18  6.631584e-19
# 9997  2.436136e-19  3.877202e-08  ...  5.478539e-33  7.324446e-32
# 9998  1.652970e-10  3.463490e-04  ...  9.260921e-11  2.017111e-10
# 9999  1.255578e-31  3.086089e-13  ...  1.218388e-16  8.526935e-16
#
# [10000 rows x 200 columns]

# %%
! python generate_dataset.py --checkpoint_path checkpoints/Atlanta_netG_epoch_10.pth --output_path output/Atlanta10 --dataset accident --dataset_path none --size 10000 --seqlen 8

# %%
import numpy as np
import pandas as pd

raw = np.load('output/'+'Atlanta10'+'.npy')
print(raw.shape)
raw = raw.reshape(-1,8*25)
print(raw.shape)

df = pd.DataFrame(raw)
