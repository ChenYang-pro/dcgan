# %% [markdown]
# # data_test

# %% [markdown]
# # 新段落

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install torch==1.0.0

# %%
# !git clone https://github.com/mhsamavatian/DAP
# Out:
# fatal: destination path 'DAP' already exists and is not an empty directory.

# %%
# %cd /content/DAP/data
# Out:
# /content/DAP/data

# %%
# !ls -a
# Out:
# .	   geohash_to_poi_vec.csv   sample_daylight.csv    train_set.7z
# ..	   geohash_to_text_vec.csv  Sample_Weather.tar.gz
# .DS_Store  readme.md		    train_set

# %%
# !apt-get install p7zip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip is already the newest version (16.02+dfsg-6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.

# %%
!7z x train_set.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 7399321 bytes (7226 KiB)
#
# Extracting archive: train_set.7z
# --
# Path = train_set.7z
# Type = 7z
# Physical Size = 7399321
# Headers Size = 533
# Method = LZMA2:26
# Solid = +
# Blocks = 1
#
#   0%
# Would you like to replace the existing file:
#   Path:     ./train_set/X_test_Atlanta.npy
#   Size:     6694109 bytes (6538 KiB)
#   Modified: 2019-04-20 09:36:17
# with the file from archive:
#   Path:     train_set/X_test_Atlanta.npy
#   Size:     6694109 bytes (6538 KiB)
#   Modified: 2019-04-20 09:36:17
# ? (Y)es / (N)o / (A)lways / (S)kip all / A(u)to rename all / (Q)uit? Y
#
#   0% 1 - train_set/X_test_Atlanta.npy
# Would you like to replace the existing file:
#   Path:     ./train_set/X_test_Austin.npy
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Colab Notebooks/pytorch-GAN-timeseries
# Out:
# /content/drive/My Drive/Colab Notebooks/pytorch-GAN-timeseries

# %%
! pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/pytorch-GAN-timeseries

# %%
! python accident_dataset.py
# Out:
# (36994, 200)
# (7974, 200)
# (7974, 8, 25)
# 0 torch.Size([64, 8, 25])
# 0

# %% [markdown]
# # run

# %%
! pip install torchvision==0.2.1

# %%
! pip install Pillow==6.1

# %%
! pip install tensorboardX==1.6

# %%
! python main.py --dataset accident --dataset_path /content/DAP/data/ --city Austin --batchSize 128 --gen_type lstm
# Out:
# Namespace(alternate=False, batchSize=128, checkpoint_every=5, city='Austin', cuda=False, dataset='accident', dataset_path='/content/DAP/data/', delta_condition=False, delta_lambda=10, dis_type='cnn', epochs=50, gen_type='lstm', imf='images', logdir='log', lr=0.0002, manualSeed=None, netD='', netG='', nz=100, outf='checkpoints', run_tag='', tensorboard_image_every=5, workers=2)
# Random Seed:  1032
# You have a cuda device, so you might want to run with --cuda as option
# (27554, 200)
# (4274, 200)
# (4274, 8, 25)
# |Discriminator Architecture|
#  CausalConvDiscriminator(
#   (tcn): TCN(
#     (tcn): TemporalConvNet(
#       (network): Sequential(
#         (0): TemporalBlock(
#           (conv1): Conv1d(25, 10, kernel_size=(8,), stride=(1,), padding=(7,))
#           (chomp1): Chomp1d()
#           (relu1): ReLU()
#           (dropout1): Dropout(p=0)
#           (conv2): Conv1d(10, 10, kernel_size=(8,), stride=(1,), padding=(7,))
#           (chomp2): Chomp1d()
# ...

# %%
#! python main.py --dataset accident --dataset_path /content/DAP/data/ --dis_type lstm

# %%
! python generate_dataset.py --checkpoint_path checkpoints/Austin_netG_epoch_25.pth --output_path output/Austin25 --dataset accident --dataset_path none --size 10000 --seqlen 8
# Out:
# Traceback (most recent call last):
#   File "generate_dataset.py", line 32, in <module>
#     generator.generate_dataset(outfile=opt.output_path, batch_size=64, delta_list=delta_list, size=int(opt.size))
#   File "/content/drive/My Drive/Colab Notebooks/pytorch-GAN-timeseries/utils.py", line 88, in generate_dataset
#     np.save(outfile, out_tensor.detach().numpy())
#   File "<__array_function__ internals>", line 6, in save
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py", line 541, in save
#     fid = open(file, "wb")
# FileNotFoundError: [Errno 2] No such file or directory: 'output/Austin25.npy'

# %%
import numpy as np
import pandas as pd

raw = np.load('output/'+'Austin25'+'.npy')
print(raw.shape)
raw = raw.reshape(-1,8*25)
print(raw.shape)

df = pd.DataFrame(raw)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-1388665a3f80> in <module>()
#       2 import pandas as pd
#       3
# ----> 4 raw = np.load('output/'+'Austin25'+'.npy')
#       5 print(raw.shape)
#       6 raw = raw.reshape(-1,8*25)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/Austin25.npy'

# %%
! python generate_dataset.py --checkpoint_path checkpoints/Austin_netG_epoch_30.pth --output_path output/Austin30 --dataset accident --dataset_path none --size 10000 --seqlen 8

# %%
import numpy as np
import pandas as pd

raw = np.load('output/'+'Austin30'+'.npy')
print(raw.shape)
raw = raw.reshape(-1,8*25)
print(raw.shape)

df = pd.DataFrame(raw)
df

# %%
! python generate_dataset.py --checkpoint_path checkpoints/Austin_netG_epoch_49.pth --output_path output/Austin49 --dataset accident --dataset_path none --size 10000 --seqlen 8

# %%
import numpy as np
import pandas as pd

raw = np.load('output/'+'Austin49'+'.npy')
print(raw.shape)
raw = raw.reshape(-1,8*25)
print(raw.shape)

df = pd.DataFrame(raw)
df
